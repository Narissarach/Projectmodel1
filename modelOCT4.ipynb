# %% [markdown]
# <a href="https://colab.research.google.com/github/Narissarach/Projectmodel1/blob/main/modelOCT4.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # ModelOCT

# %%
pip install opencv-python
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: opencv-python in /usr/local/lib/python3.9/dist-packages (4.7.0.72)
# Requirement already satisfied: numpy>=1.17.3 in /usr/local/lib/python3.9/dist-packages (from opencv-python) (1.22.4)

# %%
import os,cv2
import numpy as np
import matplotlib.pyplot as plt
import pathlib
import glob
import PIL
import plotly
import plotly.graph_objs as go
import pandas as pd
from numpy import array
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras import Sequential
from tensorflow.keras.layers import (Dense, Conv2D, AveragePooling2D, Flatten, Dropout, BatchNormalization, MaxPool2D)
import time
from keras.preprocessing import image
from tensorflow.keras.preprocessing.image import load_img, img_to_array
from keras.utils import np_utils
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers
from tensorflow.keras.models import Model, load_model
from tensorflow.keras.models import model_from_json
from tensorflow.keras.models import Sequential
import requests
from IPython.display import Image
from io import BytesIO  
import pickle as p 
import plotly.graph_objs as go  
from sklearn.utils import shuffle
from sklearn.model_selection import train_test_split
from keras import backend as K
K.image_data_format()
from keras.utils import np_utils
from sklearn.model_selection import train_test_split

# %% [markdown]
# ## เตรียมชุดของข้อมูล

# %%
from google.colab import drive # เชื่อม drive ของเรา ถ้าเชื่อมสำเร็จจะขึ้นคำว่า Mounted at /content/drive 
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import os # os จัดการเกี่ยวกับไฟล์ต่างๆ ในโฟล์เดอร์
path = '/content/drive/My Drive/Projecteye/model1'  # data เราอยู่โฟล์เดอร์ไหน

# %%
batch_size = 32   # กำหนดขนาดของแต่ละการอ่านข้อมูล
img_height = 256  # ความสูงของรูปภาพแต่ละรูป
img_width = 256   # ความกว้างของรูปภาพแต่ละรูป

num_classes = 4

# %% [markdown]
# ## Train

# %%
# Train
train_dir = "/content/drive/My Drive/Projecteye/model1/train"
train_datagen = ImageDataGenerator(rescale = 1./255)

train_set = train_datagen.flow_from_directory(train_dir, target_size=(img_height, img_width), batch_size=batch_size, class_mode='categorical')
# Out:
# Found 448 images belonging to 4 classes.

# %%
print('Train')
ids, counts = np.unique(train_set.classes, return_counts=True)
print(ids)        # คลาส
print(counts)     # จำนวนภาพของคลาส
# Out:
# Train
# [0 1 2 3]
# [112 112 112 112]

# %%
train_set[0][0][0].shape   # W*H*3 (3 Channel RGB)
# Out:
# (256, 256, 3)

# %% [markdown]
# ## Validation

# %%
# Validation
val_dir ="/content/drive/My Drive/Projecteye/model1/validation"
val_datagen = ImageDataGenerator(rescale = 1./255)

val_set = val_datagen.flow_from_directory(val_dir, target_size=(img_height, img_width), batch_size=batch_size, class_mode='categorical')
# Out:
# Found 56 images belonging to 4 classes.

# %%
print('Validation')
ids, counts = np.unique(val_set.classes, return_counts=True)
print(ids)        # คลาส
print(counts)     # จำนวนข้อมูลของคลาส
# Out:
# Validation
# [0 1 2 3]
# [14 14 14 14]

# %% [markdown]
# ## Test

# %%
# Test
test_dir ="/content/drive/My Drive/Projecteye/model1/test"
test_datagen = ImageDataGenerator(rescale = 1./255)

test_set = tf.keras.utils.image_dataset_from_directory(test_dir,image_size=(img_height, img_width))
# Out:
# Found 56 files belonging to 4 classes.

# %%
class_names = test_set.class_names
print(class_names)
# Out:
# ['CSC', 'Normal', 'PCV', 'VKH']

# %% [markdown]
# ## Training

# %% [markdown]
# ### สร้าง Model

# %%
num_classes = 4
epochs=30   # จำนวนครั้งที่เราจะ Train
# ขนาดภาพอินพุตเข้าสู่ Model
in_shape = (256,256,3)
in_shape
# Out:
# (256, 256, 3)

# %%
model = Sequential()   # สร้าง Model

# สร้างชั้น Convolution ชั้นแรก ค่าพารามิเตอร์ activation ใช้ ReLU
model.add(Conv2D(16, (3,3), activation = 'relu', input_shape = in_shape))
model.add(MaxPool2D((2,2)))    # สร้างชั้น Max Pooling ค่าพารามิเตอร์ 2,2 คือ Pool Size

# ชั้นที่ 2
model.add(Conv2D(32, (3,3), activation = 'relu'))
model.add(MaxPool2D((2,2)))

# ชั้นที่ 3 
model.add(Conv2D(64, (3,3), activation='relu'))
model.add(MaxPool2D((2,2)))


# FULLY CONNECTED LAYER
model.add(Flatten())
model.add(Dense(64, activation='relu'))
# Output layer
model.add(Dense(4, activation='softmax')) # 4 คลาส
model.summary()          # ดูสรุปโครงสร้าง Model
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d (Conv2D)             (None, 254, 254, 16)      448
#
#  max_pooling2d (MaxPooling2D  (None, 127, 127, 16)     0
#  )
#
#  conv2d_1 (Conv2D)           (None, 125, 125, 32)      4640
#
#  max_pooling2d_1 (MaxPooling  (None, 62, 62, 32)       0
#  2D)
#
#  conv2d_2 (Conv2D)           (None, 60, 60, 64)        18496
#
#  max_pooling2d_2 (MaxPooling  (None, 30, 30, 64)       0
#  2D)
#
#  flatten (Flatten)           (None, 57600)             0
#
#  dense (Dense)               (None, 64)                3686464
#
#  dense_1 (Dense)             (None, 4)                 260
#
# =================================================================
# Total params: 3,710,308
# Trainable params: 3,710,308
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# ##### ดู kernel

# %%
for layer in model.layers:
  if 'conv' not in layer.name:
       continue
  kernels, biases = layer.get_weights()
  print(layer.name, 'shape:', kernels.shape)
# Out:
# conv2d shape: (3, 3, 3, 16)
# conv2d_1 shape: (3, 3, 16, 32)
# conv2d_2 shape: (3, 3, 32, 64)

# %%
k_min, k_max = kernels.min(), kernels.max()
kernels = (kernels - k_min)/ (k_max - k_min)
kernel_idx = 0
kernel_i = kernels[:, :, 0, kernel_idx]
print(kernel_i.round(2))
# Out:
# [[0.37 0.85 0.62]
#  [0.47 0.04 0.76]
#  [0.23 0.58 0.09]]

# %%
nplots = 15
fig = plt.figure(figsize = (10, 8))
for j in range(nplots):
  plt.subplot(5, 5, j+1)
  plt.imshow(kernels[:, :, 0, j], cmap = plt.cm.gray)
  plt.title(j)
  plt.xticks([]); plt.yticks([])
plt.show()

# %%
image = load_img('/content/drive/My Drive//Projecteye/model1/train/CSC/GE8938 12-13-16 LE_000006_cropped.png', target_size=(256, 256))
plt.imshow(image)
plt.show()

# %%
img1 = img_to_array(image)
print('shape =', img1.shape)
print('max pixel value =', np.max(img1))
# Out:
# shape = (256, 256, 3)
# max pixel value = 255.0

# %% [markdown]
# ### Compile และ Train

# %%
model.compile(loss = 'categorical_crossentropy', optimizer = 'adam', metrics = ['accuracy'])

# %%
start = time.time()

history = model.fit(train_set, steps_per_epoch=len(train_set), 
                    validation_data=val_set, 
                    epochs=30,verbose=1)

end = time.time()
print("Time Taken: {:.2f} minutes".format((end-start)/60))
# Out:
# Epoch 1/30
# 14/14 [==============================] - 11s 466ms/step - loss: 1.6904 - accuracy: 0.2656 - val_loss: 1.3836 - val_accuracy: 0.2857
# Epoch 2/30
# 14/14 [==============================] - 5s 359ms/step - loss: 1.3583 - accuracy: 0.2857 - val_loss: 1.3268 - val_accuracy: 0.3214
# Epoch 3/30
# 14/14 [==============================] - 4s 279ms/step - loss: 1.2764 - accuracy: 0.4107 - val_loss: 1.3010 - val_accuracy: 0.3929
# Epoch 4/30
# 14/14 [==============================] - 4s 291ms/step - loss: 1.2078 - accuracy: 0.4598 - val_loss: 1.3654 - val_accuracy: 0.3393
# Epoch 5/30
# 14/14 [==============================] - 4s 277ms/step - loss: 1.1108 - accuracy: 0.5446 - val_loss: 1.4113 - val_accuracy: 0.3750
# Epoch 6/30
# 14/14 [==============================] - 4s 273ms/step - loss: 0.9577 - accuracy: 0.6362 - val_loss: 1.4108 - val_accuracy: 0.3571
# Epoch 7/30
# 14/14 [==============================] - 4s 292ms/step - loss: 0.7826 - accuracy: 0.7031 - val_loss: 1.4018 - val_accuracy: 0.4464
# Epoch 8/30
# 14/14 [==============================] - 4s 278ms/step - loss: 0.5719 - accuracy: 0.7991 - val_loss: 1.6717 - val_accuracy: 0.4464
# Epoch 9/30
# 14/14 [==============================] - 4s 275ms/step - loss: 0.4005 - accuracy: 0.8728 - val_loss: 1.5833 - val_accuracy: 0.4107
# Epoch 10/30
# 14/14 [==============================] - 4s 286ms/step - loss: 0.2533 - accuracy: 0.9241 - val_loss: 1.6917 - val_accuracy: 0.4464
# Epoch 11/30
# 14/14 [==============================] - 4s 291ms/step - loss: 0.1293 - accuracy: 0.9688 - val_loss: 1.6665 - val_accuracy: 0.4643
# Epoch 12/30
# 14/14 [==============================] - 4s 294ms/step - loss: 0.0805 - accuracy: 0.9821 - val_loss: 1.9326 - val_accuracy: 0.5536
# Epoch 13/30
# 14/14 [==============================] - 5s 313ms/step - loss: 0.0439 - accuracy: 0.9933 - val_loss: 2.0339 - val_accuracy: 0.5357
# Epoch 14/30
# 14/14 [==============================] - 4s 287ms/step - loss: 0.0201 - accuracy: 1.0000 - val_loss: 2.1196 - val_accuracy: 0.5179
# Epoch 15/30
# 14/14 [==============================] - 4s 285ms/step - loss: 0.0064 - accuracy: 1.0000 - val_loss: 2.3489 - val_accuracy: 0.5179
# Epoch 16/30
# 14/14 [==============================] - 4s 290ms/step - loss: 0.0040 - accuracy: 1.0000 - val_loss: 2.3933 - val_accuracy: 0.5179
# Epoch 17/30
# 14/14 [==============================] - 4s 287ms/step - loss: 0.0026 - accuracy: 1.0000 - val_loss: 2.4630 - val_accuracy: 0.5179
# Epoch 18/30
# 14/14 [==============================] - 4s 275ms/step - loss: 0.0018 - accuracy: 1.0000 - val_loss: 2.5698 - val_accuracy: 0.4821
# Epoch 19/30
# 14/14 [==============================] - 4s 277ms/step - loss: 0.0015 - accuracy: 1.0000 - val_loss: 2.5836 - val_accuracy: 0.5179
# Epoch 20/30
# 14/14 [==============================] - 4s 289ms/step - loss: 0.0013 - accuracy: 1.0000 - val_loss: 2.6382 - val_accuracy: 0.5000
# Epoch 21/30
# 14/14 [==============================] - 4s 278ms/step - loss: 0.0011 - accuracy: 1.0000 - val_loss: 2.7056 - val_accuracy: 0.5179
# Epoch 22/30
# 14/14 [==============================] - 4s 284ms/step - loss: 9.5981e-04 - accuracy: 1.0000 - val_loss: 2.7115 - val_accuracy: 0.5179
# Epoch 23/30
# 14/14 [==============================] - 4s 282ms/step - loss: 8.4493e-04 - accuracy: 1.0000 - val_loss: 2.7657 - val_accuracy: 0.5000
# Epoch 24/30
# 14/14 [==============================] - 4s 278ms/step - loss: 7.6108e-04 - accuracy: 1.0000 - val_loss: 2.7918 - val_accuracy: 0.5179
# Epoch 25/30
# 14/14 [==============================] - 4s 282ms/step - loss: 6.9351e-04 - accuracy: 1.0000 - val_loss: 2.8250 - val_accuracy: 0.5000
# Epoch 26/30
# 14/14 [==============================] - 4s 292ms/step - loss: 6.3339e-04 - accuracy: 1.0000 - val_loss: 2.8480 - val_accuracy: 0.5179
# Epoch 27/30
# 14/14 [==============================] - 4s 284ms/step - loss: 5.7234e-04 - accuracy: 1.0000 - val_loss: 2.8639 - val_accuracy: 0.5000
# Epoch 28/30
# 14/14 [==============================] - 4s 272ms/step - loss: 5.2676e-04 - accuracy: 1.0000 - val_loss: 2.8888 - val_accuracy: 0.5000
# Epoch 29/30
# 14/14 [==============================] - 4s 297ms/step - loss: 4.8459e-04 - accuracy: 1.0000 - val_loss: 2.9303 - val_accuracy: 0.5000
# Epoch 30/30
# 14/14 [==============================] - 4s 281ms/step - loss: 4.5334e-04 - accuracy: 1.0000 - val_loss: 2.9375 - val_accuracy: 0.5000
# Time Taken: 2.16 minutes

# %% [markdown]
# ### Save Model

# %%
modelOCT = '/Model'
if not os.path.exists(path+modelOCT):
    os.makedirs(path+modelOCT)
os.makedirs('/content/drive/My Drive/Projecteye/savemodel/', exist_ok=True)
model.save('/content/drive/MyDrive/Projecteye/savemodel/modelOCT4.h5')

with open('history_model', 'wb') as file:
   p.dump(history.history, file)

filepath='modelOCT4.h5'
model.save(filepath)
filepath_model = 'modelOCT4.json'
filepath_weights = 'weightsmodel4.h5'
model_json = model.to_json()
with open(filepath_model, "w") as json_file:
   json_file.write(model_json)

model.save_weights('weightsmodel4.h5')
print("Saved model to disk")
# Out:
# Saved model to disk

# %% [markdown]
# ### Load Model

# %%
with open('history_model', 'rb') as file:
   his = p.load(file)

h1 = go.Scatter(y=his['val_accuracy'],
mode="lines", line=dict(
width=2,
color='blue'),
name="val_accuracy"
)
h2 = go.Scatter(y=his['val_loss'],
mode="lines", line=dict(
width=2,
color='red'),
name="val_loss"
)

data = [h1,h2]
layout1 = go.Layout(title='Loss',
xaxis=dict(title='epochs'),
yaxis=dict(title=' '))
fig1 = go.Figure(data, layout=layout1)
plotly.offline.iplot(fig1, filename="testOCT")
predict_model = load_model(filepath)
predict_model.summary()
with open(filepath_model, 'r') as f:
   loaded_model_json = f.read()
predict_model = model_from_json(loaded_model_json)
predict_model.load_weights(filepath_weights)
print("Loaded model from disk")
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.18.2.min.js"></script>                <div id="6d05254b-4654-405a-943e-582bc41be070" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("6d05254b-4654-405a-943e-582bc41be070")) {                    Plotly.newPlot(                        "6d05254b-4654-405a-943e-582bc41be070",                        [{"line":{"color":"blue","width":2},"mode":"lines","name":"val_accuracy","y":[0.2857142984867096,0.3214285671710968,0.3928571343421936,0.3392857015132904,0.375,0.3571428656578064,0.4464285671710968,0.4464285671710968,0.4107142984867096,0.4464285671710968,0.4642857015132904,0.5535714030265808,0.5357142686843872,0.5178571343421936,0.5178571343421936,0.5178571343421936,0.5178571343421936,0.4821428656578064,0.5178571343421936,0.5,0.5178571343421936,0.5178571343421936,0.5,0.5178571343421936,0.5,0.5178571343421936,0.5,0.5,0.5,0.5],"type":"scatter"},{"line":{"color":"red","width":2},"mode":"lines","name":"val_loss","y":[1.38355553150177,1.3268159627914429,1.3010190725326538,1.3653621673583984,1.411307454109192,1.4107502698898315,1.4018336534500122,1.6716870069503784,1.5833337306976318,1.6917377710342407,1.6665019989013672,1.93260657787323,2.0339014530181885,2.1196231842041016,2.3489015102386475,2.393301248550415,2.462980270385742,2.569841146469116,2.5836195945739746,2.638209104537964,2.7056448459625244,2.7114522457122803,2.765747547149658,2.791827440261841,2.824988603591919,2.8479983806610107,2.8639280796051025,2.8888392448425293,2.930323362350464,2.9375150203704834],"type":"scatter"}],                        {"template":{"data":{"barpolar":[{"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"barpolar"}],"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"carpet":[{"aaxis":{"endlinecolor":"#2a3f5f","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"#2a3f5f"},"baxis":{"endlinecolor":"#2a3f5f","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"#2a3f5f"},"type":"carpet"}],"choropleth":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"choropleth"}],"contourcarpet":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"contourcarpet"}],"contour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"contour"}],"heatmapgl":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmapgl"}],"heatmap":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmap"}],"histogram2dcontour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.88888888888888 ...
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d (Conv2D)             (None, 254, 254, 16)      448
#
#  max_pooling2d (MaxPooling2D  (None, 127, 127, 16)     0
#  )
#
#  conv2d_1 (Conv2D)           (None, 125, 125, 32)      4640
#
#  max_pooling2d_1 (MaxPooling  (None, 62, 62, 32)       0
#  2D)
#
#  conv2d_2 (Conv2D)           (None, 60, 60, 64)        18496
#
#  max_pooling2d_2 (MaxPooling  (None, 30, 30, 64)       0
#  2D)
#
#  flatten (Flatten)           (None, 57600)             0
#
#  dense (Dense)               (None, 64)                3686464
#
#  dense_1 (Dense)             (None, 4)                 260
#
# =================================================================
# Total params: 3,710,308
# Trainable params: 3,710,308
# Non-trainable params: 0
# _________________________________________________________________
# Loaded model from disk

# %% [markdown]
# ## ประเมิน

# %%
plt.figure(figsize = (10, 3.5))
plt.subplot(1, 2 , 1)
plt.title('Loss')
plt.plot(history.history['loss'], label = 'Train Loss')
plt.plot(history.history['val_loss'], 'r', lw = 3.2, label = 'Validation loss')
plt.legend()

# %%
plt.subplot(1, 2, 2)
plt.title('Accuracy')
plt.plot(history.history['accuracy'], label = 'Train')
plt.plot(history.history['val_accuracy'], 'r', lw = 3.2, label = 'Validation')
plt.legend()
plt.tight_layout()
plt.show()

# %%
acc = model.evaluate(val_set, steps = len(val_set), verbose = 0)
print('score = {:.3f}' .format(acc[1]))
# Out:
# score = 0.500

# %% [markdown]
# ### Prediction

# %%
import requests
from IPython.display import Image
from io import BytesIO
from sklearn.metrics import confusion_matrix
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
from keras.preprocessing import image
from keras.preprocessing import image 
import keras.utils as image
from keras.models import load_model

# %%
train_set.class_indices
# Out:
# {'CSC': 0, 'Normal': 1, 'PCV': 2, 'VKH': 3}

# %%
# CSC
test_path = ('/content/drive/My Drive/Projecteye/model1/test/CSC/CD7445 22-07-16 LE_001_cropped.png')
img = keras.preprocessing.image.load_img(
test_path, target_size=(img_height, img_width)
)
img_array = keras.preprocessing.image.img_to_array(img)
img_array = tf.expand_dims(img_array, 0) # Create a batch
predictions = predict_model.predict(img_array)
score = tf.nn.softmax(predictions[0])
print("CSC",score[0],"Normal",score[1],"PCV",score[2],"VKH",score[3])
display(Image(filename=test_path,width=256, height=256))
if score[0]==np.max(score):
  eye = "CSC"
elif score[1]==np.max(score):
  eye = "Normal"
elif score[2]==np.max(score):
  eye = "PCV"
elif score[3]==np.max(score):
  eye = "VKH"
print(
"AI {} มีความมั่นใจ {:.2f}%."
.format(eye, 100 * np.max(score))
)
# Out:
# 1/1 [==============================] - 0s 187ms/step
# CSC tf.Tensor(0.47536686, shape=(), dtype=float32) Normal tf.Tensor(0.17487772, shape=(), dtype=float32) PCV tf.Tensor(0.17487772, shape=(), dtype=float32) VKH tf.Tensor(0.17487772, shape=(), dtype=float32)
# AI CSC มีความมั่นใจ 47.54%.

# %%
# Normal
test_path = ('/content/drive/My Drive/Projecteye/model1/test/Normal/AA0598 17-11-22 RE_000_cropped.png')
img = keras.preprocessing.image.load_img(
test_path, target_size=(img_height, img_width)
)
img_array = keras.preprocessing.image.img_to_array(img)
img_array = tf.expand_dims(img_array, 0) # Create a batch
predictions = predict_model.predict(img_array)
score = tf.nn.softmax(predictions[0])
print("CSC",score[0],"Normal",score[1],"PCV",score[2],"VKH",score[3])
display(Image(filename=test_path,width=256, height=256))
if score[0]==np.max(score):
  eye = "CSC"
elif score[1]==np.max(score):
  eye = "Normal"
elif score[2]==np.max(score):
  eye = "PCV"
elif score[3]==np.max(score):
  eye = "VKH"
print(
"AI {} มีความมั่นใจ {:.2f}%."
.format(eye, 100 * np.max(score))
)
# Out:
# 1/1 [==============================] - 0s 17ms/step
# CSC tf.Tensor(0.17487772, shape=(), dtype=float32) Normal tf.Tensor(0.47536686, shape=(), dtype=float32) PCV tf.Tensor(0.17487772, shape=(), dtype=float32) VKH tf.Tensor(0.17487772, shape=(), dtype=float32)
# AI Normal มีความมั่นใจ 47.54%.

# %%
# PCV
test_path = ('/content/drive/My Drive/Projecteye/model1/test/PCV/AF4715 18-10-17 LE_001_cropped.png')
img = keras.preprocessing.image.load_img(
test_path, target_size=(img_height, img_width)
)
img_array = keras.preprocessing.image.img_to_array(img)
img_array = tf.expand_dims(img_array, 0) # Create a batch
predictions = predict_model.predict(img_array)
score = tf.nn.softmax(predictions[0])
print("CSC",score[0],"Normal",score[1],"PCV",score[2],"VKH",score[3])
display(Image(filename=test_path,width=256, height=256))
if score[0]==np.max(score):
  eye = "CSC"
elif score[1]==np.max(score):
  eye = "Normal"
elif score[2]==np.max(score):
  eye = "PCV"
elif score[3]==np.max(score):
  eye = "VKH"
print(
"AI {} มีความมั่นใจ {:.2f}%."
.format(eye, 100 * np.max(score))
)
# Out:
# 1/1 [==============================] - 0s 18ms/step
# CSC tf.Tensor(0.17487772, shape=(), dtype=float32) Normal tf.Tensor(0.17487772, shape=(), dtype=float32) PCV tf.Tensor(0.47536686, shape=(), dtype=float32) VKH tf.Tensor(0.17487772, shape=(), dtype=float32)
# AI PCV มีความมั่นใจ 47.54%.

# %%
# VKH
test_path = ('/content/drive/My Drive/Projecteye/model1/test/VKH/DQ7866 20-01-20 LE_001_cropped.png')
img = keras.preprocessing.image.load_img(
test_path, target_size=(img_height, img_width)
)
img_array = keras.preprocessing.image.img_to_array(img)
img_array = tf.expand_dims(img_array, 0) # Create a batch
predictions = predict_model.predict(img_array)
score = tf.nn.softmax(predictions[0])
print("CSC",score[0],"Normal",score[1],"PCV",score[2],"VKH",score[3])
display(Image(filename=test_path,width=256, height=256))
if score[0]==np.max(score):
  eye = "CSC"
elif score[1]==np.max(score):
  eye = "Normal"
elif score[2]==np.max(score):
  eye = "PCV"
elif score[3]==np.max(score):
  eye = "VKH"
print(
"AI {} มีความมั่นใจ {:.2f}%."
.format(eye, 100 * np.max(score))
)
# Out:
# 1/1 [==============================] - 0s 18ms/step
# CSC tf.Tensor(0.17487772, shape=(), dtype=float32) Normal tf.Tensor(0.17487772, shape=(), dtype=float32) PCV tf.Tensor(0.17487772, shape=(), dtype=float32) VKH tf.Tensor(0.47536686, shape=(), dtype=float32)
# AI VKH มีความมั่นใจ 47.54%.

# %% [markdown]
# ### Testing

# %%
y_test = []; y_pred = []
class_names = test_set.class_names
for images, labels in test_set:
  for i in range(len(list(labels))):
    img_array = keras.preprocessing.image.img_to_array(images[i])
    X_test = tf.expand_dims(img_array, 0)
    score = predict_model.predict(X_test)
    if score[0][0]==np.max(score):
      eye = "CSC"
    elif score[0][1]==np.max(score):
      eye = "Normal"
    elif score[0][2]==np.max(score):
      eye = "PCV"
    elif score[0][3]==np.max(score):
      eye = "VKH"
    y_pred.append(eye)
    y_test.append(class_names[labels[i]])
# Out:
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 19ms/step

# %%
print(y_test)
print(len(y_test))
# Out:
# ['VKH', 'CSC', 'Normal', 'PCV', 'PCV', 'PCV', 'Normal', 'PCV', 'VKH', 'CSC', 'CSC', 'Normal', 'VKH', 'CSC', 'Normal', 'Normal', 'PCV', 'CSC', 'CSC', 'CSC', 'VKH', 'PCV', 'VKH', 'VKH', 'CSC', 'VKH', 'PCV', 'Normal', 'PCV', 'PCV', 'VKH', 'Normal', 'PCV', 'VKH', 'VKH', 'VKH', 'VKH', 'Normal', 'CSC', 'Normal', 'PCV', 'CSC', 'CSC', 'CSC', 'VKH', 'Normal', 'CSC', 'Normal', 'CSC', 'Normal', 'Normal', 'PCV', 'VKH', 'Normal', 'PCV', 'PCV']
# 56

# %%
print(y_pred)
print(len(y_pred))
# Out:
# ['VKH', 'CSC', 'VKH', 'VKH', 'PCV', 'CSC', 'Normal', 'CSC', 'CSC', 'CSC', 'CSC', 'Normal', 'VKH', 'VKH', 'Normal', 'Normal', 'CSC', 'CSC', 'CSC', 'VKH', 'VKH', 'VKH', 'VKH', 'VKH', 'CSC', 'Normal', 'CSC', 'Normal', 'VKH', 'Normal', 'CSC', 'Normal', 'VKH', 'VKH', 'CSC', 'CSC', 'VKH', 'VKH', 'CSC', 'Normal', 'CSC', 'Normal', 'CSC', 'CSC', 'PCV', 'VKH', 'CSC', 'Normal', 'CSC', 'Normal', 'VKH', 'PCV', 'CSC', 'Normal', 'CSC', 'PCV']
# 56

# %% [markdown]
# ## Confusion Matrix

# %%
from sklearn.metrics import confusion_matrix
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
confusion_matrix(y_test, y_pred)
# Out:
# array([[11,  1,  0,  2],
#        [ 0, 10,  0,  4],
#        [ 6,  1,  3,  4],
#        [ 5,  1,  1,  7]])

# %%
cm = confusion_matrix(y_test, y_pred)

# %%
test_set.class_names
# Out:
# ['CSC', 'Normal', 'PCV', 'VKH']

# %%
cm_df = pd.DataFrame(cm,
                     index = ['CSC', 'Normal', 'PCV', 'VKH'], 
                     columns = ['CSC', 'Normal', 'PCV', 'VKH'])

# %%
cm_df
# Out:
#         CSC  Normal  PCV  VKH
# CSC      11       1    0    2
# Normal    0      10    0    4
# PCV       6       1    3    4
# VKH       5       1    1    7

# %%
plt.figure(figsize=(10,5))
sns.heatmap(cm_df, annot=True)
plt.title('Confusion Matrix')
plt.ylabel('Actual Values')
plt.xlabel('Predicted Values')
plt.show()

# %% [markdown]
# ##  misclassify

# %%
# แสดง misclassify ว่ามีกี่ค่า
misclassify = 0
for i in range(len(cm)):
    for j in range(len(cm)):
        if i != j:
            misclassify += cm[i][j]
            
print('misclassification: ', misclassify)
# Out:
# misclassification:  25

# %%
# คำนวณค่า misclassification
misclassify = 1 - np.trace(cm) / np.sum(cm)

# Misclassification rate = จำนวนภาพที่ถูกจัดหมวดหมู่ผิด / จำนวนภาพทั้งหมดที่ใช้ในการทดสอบ

# แสดงผลลัพธ์ที่คิดเป็น %
print("Misclassification: {:.2f}%".format(misclassify*100))
# Out:
# Misclassification: 44.64%

# %%
from sklearn.metrics import accuracy_score
from sklearn.metrics import recall_score
from sklearn.metrics import precision_score
from sklearn.metrics import f1_score

# %%
# accuracy: (tp + tn) / (p + n)
accuracy = accuracy_score(y_test, y_pred)
print('Accuracy: %f' % accuracy)
# Out:
# Accuracy: 0.553571

# %%
# recall: tp / (tp + fn)
recall = recall_score(y_test, y_pred, average='weighted') ### ในส่วนของ average='weighted' หนูไม่มั่นใจว่าควรใส่เป็น macro, micro หรือ weight
print('Recall: %f' % recall)
# Out:
# Recall: 0.553571

# %%
# precision tp / (tp + fp)
precision = precision_score(y_test, y_pred, average='weighted') ### ในส่วนของ average='weighted' หนูไม่มั่นใจว่าควรใส่เป็น macro, micro หรือ weight
print('Precision: %f' % precision)
# Out:
# Precision: 0.607749

# %%
# f1: 2 tp / (2 tp + fp + fn)
f1 = f1_score(y_test, y_pred, average='weighted') ### ในส่วนของ average='weighted' หนูไม่มั่นใจว่าควรใส่เป็น macro, micro หรือ weight
print('F1 score: %f' % f1)
# Out:
# F1 score: 0.534200
